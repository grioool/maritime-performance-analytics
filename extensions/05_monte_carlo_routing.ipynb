# %% [markdown]
# # Extension 5 - Monte Carlo routing under weather uncertainty
#
# This notebook runs the reproducible Monte Carlo routing extension implemented in `05_monte_carlo_routing.py`.
#
# The extension samples historical weather conditions along a feasible observed-water graph, compares shortest-route and Monte Carlo routes, and saves route confidence intervals for fuel, CO2, ETA, and rotor benefit under `../results/`.

# %%
# %run 05_monte_carlo_routing.py
# Out:
# Loading engineered dataset...
# Selected Voyage_ID: 364
# Reference voyage points: 573
# Start/end: (53.635, -0.173) -> (61.190, 6.058)
# Detected 4 sailing legs and 3 stop gaps (gap threshold > 2.0 h)
#   Leg 1: 2025-01-06 14:57:42 -> 2025-01-07 06:02:27, observed 199.1 nm, straight 195.5 nm, 116 points
#   Leg 2: 2025-01-07 11:40:30 -> 2025-01-07 14:08:12, observed 20.1 nm, straight 6.9 nm, 18 points
#   Leg 3: 2025-01-07 19:39:50 -> 2025-01-09 12:58:15, observed 516.6 nm, straight 481.2 nm, 313 points
#   Leg 4: 2025-01-09 16:06:07 -> 2025-01-10 05:37:28, observed 127.9 nm, straight 79.1 nm, 126 points
# Base speed: 11.70 kn
# Loading Natural Earth land mask: C:\Users\hucu\Desktop\maritime-performance-analytics\data\geo\ne_10m_land.geojson
# Land mask: 65 polygons, 87,444 coastline segments in route bounds, AIS corridor override 14.0 nm
# Graph: 537 navigable nodes, 3,784 directed edges, observed-water radius 55.0 nm, land mask on
# AIS-corridor override edges: 132
# ...

# %% [markdown]
# Generated outputs:
#
# - `../results/monte_carlo_routing.png`
# - `../results/monte_carlo_route_summary.csv`
# - `../results/monte_carlo_route_metrics.csv`
# - `../results/monte_carlo_route_paths.csv`
# - `../results/monte_carlo_edge_frequency.csv`
# - `../results/monte_carlo_route_summary.txt`
